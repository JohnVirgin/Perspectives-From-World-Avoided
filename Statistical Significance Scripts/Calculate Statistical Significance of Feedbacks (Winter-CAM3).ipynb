# %%
## Import Packages
import numpy as np
import scipy.stats as stats
import warnings
import pickle
import Area_Avg
from netCDF4 import Dataset
warnings.filterwarnings('ignore')

# %%
#RCP45 Arctic
RCP45_DYNatmos_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Dynamical/RCP45/Seasonal Breakdown/RCP45_DYNatmos_EnergyB_DJF_AA.pickle","rb"))
RCP45_OCN_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Ocean Heat Content/RCP45/Seasonal Breakdown/RCP45_OCN_EnergyB_DJF_AA.pickle","rb"))
RCP45_RF_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Forcing/RCP45/Seasonal Breakdown/RCP45_RF_EnergyB_DJF_AA.pickle","rb"))

CAM3_RCP45_LR_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/RCP45/Seasonal Breakdown/CAM3_RCP45_LR_EnergyB_DJF_AA.pickle","rb"))
CAM3_RCP45_WV_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/RCP45/Seasonal Breakdown/CAM3_RCP45_WV_EnergyB_DJF_AA.pickle","rb"))
CAM3_RCP45_ALB_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Albedo/RCP45/Seasonal Breakdown/CAM3_RCP45_ALB_EnergyB_DJF_AA.pickle","rb"))
CAM3_RCP45_CLD_LW_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_LW_EnergyB_DJF_AA.pickle","rb"))
CAM3_RCP45_CLD_SW_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_SW_EnergyB_DJF_AA.pickle","rb"))

#RCP45 Global
RCP45_OCN_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Ocean Heat Content/RCP45/Seasonal Breakdown/RCP45_OCN_EnergyB_DJF_GA.pickle","rb"))
RCP45_RF_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Forcing/RCP45/Seasonal Breakdown/RCP45_RF_EnergyB_DJF_GA.pickle","rb"))

CAM3_RCP45_LR_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/RCP45/Seasonal Breakdown/CAM3_RCP45_LR_EnergyB_DJF_GA.pickle","rb"))
CAM3_RCP45_WV_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/RCP45/Seasonal Breakdown/CAM3_RCP45_WV_EnergyB_DJF_GA.pickle","rb"))
CAM3_RCP45_ALB_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Albedo/RCP45/Seasonal Breakdown/CAM3_RCP45_ALB_EnergyB_DJF_GA.pickle","rb"))
CAM3_RCP45_CLD_LW_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_LW_EnergyB_DJF_GA.pickle","rb"))
CAM3_RCP45_CLD_SW_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_SW_EnergyB_DJF_GA.pickle","rb"))

#wAVD Arctic
wAVD_DYNatmos_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Dynamical/wAVD/Seasonal Breakdown/wAVD_DYNatmos_EnergyB_DJF_AA.pickle","rb"))
wAVD_OCN_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Ocean Heat Content/wAVD/Seasonal Breakdown/wAVD_OCN_EnergyB_DJF_AA.pickle","rb"))
wAVD_RF_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Forcing/wAVD/Seasonal Breakdown/wAVD_RF_EnergyB_DJF_AA.pickle","rb"))

CAM3_wAVD_LR_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/wAVD/Seasonal Breakdown/CAM3_wAVD_LR_EnergyB_DJF_AA.pickle","rb"))
CAM3_wAVD_WV_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/wAVD/Seasonal Breakdown/CAM3_wAVD_WV_EnergyB_DJF_AA.pickle","rb"))
CAM3_wAVD_ALB_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Albedo/wAVD/Seasonal Breakdown/CAM3_wAVD_ALB_EnergyB_DJF_AA.pickle","rb"))
CAM3_wAVD_CLD_LW_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_LW_EnergyB_DJF_AA.pickle","rb"))
CAM3_wAVD_CLD_SW_EnergyB_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_SW_EnergyB_DJF_AA.pickle","rb"))

#wAVD Global
wAVD_OCN_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Ocean Heat Content/wAVD/Seasonal Breakdown/wAVD_OCN_EnergyB_DJF_GA.pickle","rb"))
wAVD_RF_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Forcing/wAVD/Seasonal Breakdown/wAVD_RF_EnergyB_DJF_GA.pickle","rb"))

CAM3_wAVD_LR_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/wAVD/Seasonal Breakdown/CAM3_wAVD_LR_EnergyB_DJF_GA.pickle","rb"))
CAM3_wAVD_WV_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/wAVD/Seasonal Breakdown/CAM3_wAVD_WV_EnergyB_DJF_GA.pickle","rb"))
CAM3_wAVD_ALB_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Albedo/wAVD/Seasonal Breakdown/CAM3_wAVD_ALB_EnergyB_DJF_GA.pickle","rb"))
CAM3_wAVD_CLD_LW_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_LW_EnergyB_DJF_GA.pickle","rb"))
CAM3_wAVD_CLD_SW_EnergyB_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_SW_EnergyB_DJF_GA.pickle","rb"))

# %%
#CAM3 Horizontal resolution grid
LLL3 = Dataset('Kernels/Interpolated/CAM3_Kernels.nc')
CAM3_Lat = np.squeeze(LLL3.variables['lat'])
CAM3_Lon = np.squeeze(LLL3.variables['lon'])

#Lists for iterating
Months = np.arange(0,12)
FP_Ensemble_Members = np.arange(0,5)

RCP45_dST_CAM3Grid = np.swapaxes(pickle.load(open(\
   "Future Projection CC Responses/RCP45_dST_CAM3Grid.pickle","rb"),encoding='latin1'),2,3)

wAVD_dST_CAM3Grid = np.swapaxes(pickle.load(open(\
   "Future Projection CC Responses/wAVD_dST_CAM3Grid.pickle","rb"),encoding='latin1'),2,3)

RCP45_dST_CAM3Grid_AA = np.zeros([5,12])
RCP45_dST_CAM3Grid_GA = np.zeros([5,12])

wAVD_dST_CAM3Grid_AA = np.zeros([5,12])
wAVD_dST_CAM3Grid_GA = np.zeros([5,12])

for i in range(FP_Ensemble_Members.size):
    RCP45_dST_CAM3Grid_AA[i,:] = Area_Avg.LatLonavg_Time(\
    RCP45_dST_CAM3Grid[i,:,54:,:],CAM3_Lat[54:],CAM3_Lon)
    
    RCP45_dST_CAM3Grid_GA[i,:] = Area_Avg.LatLonavg_Time(\
    RCP45_dST_CAM3Grid[i,:,:,:],CAM3_Lat,CAM3_Lon)
    
    wAVD_dST_CAM3Grid_AA[i,:] = Area_Avg.LatLonavg_Time(\
    wAVD_dST_CAM3Grid[i,:,54:,:],CAM3_Lat[54:],CAM3_Lon)
    
    wAVD_dST_CAM3Grid_GA[i,:] = Area_Avg.LatLonavg_Time(\
    wAVD_dST_CAM3Grid[i,:,:,:],CAM3_Lat,CAM3_Lon)
    
RCP45_dST_CAM3Grid_DJF_AA = np.mean(\
                            np.stack((RCP45_dST_CAM3Grid_AA[:,0],\
                                           RCP45_dST_CAM3Grid_AA[:,1],\
                                           RCP45_dST_CAM3Grid_AA[:,11]),axis=1),axis=1)
RCP45_dST_CAM3Grid_DJF_GA = np.mean(\
                            np.stack((RCP45_dST_CAM3Grid_GA[:,0],\
                                           RCP45_dST_CAM3Grid_GA[:,1],\
                                           RCP45_dST_CAM3Grid_GA[:,11]),axis=1),axis=1)

wAVD_dST_CAM3Grid_DJF_AA = np.mean(\
                            np.stack((wAVD_dST_CAM3Grid_AA[:,0],\
                                           wAVD_dST_CAM3Grid_AA[:,1],\
                                           wAVD_dST_CAM3Grid_AA[:,11]),axis=1),axis=1)
wAVD_dST_CAM3Grid_DJF_GA = np.mean(\
                            np.stack((wAVD_dST_CAM3Grid_GA[:,0],\
                                           wAVD_dST_CAM3Grid_GA[:,1],\
                                           wAVD_dST_CAM3Grid_GA[:,11]),axis=1),axis=1)

RCP45_OCN_Feedback_DJF_AA = RCP45_OCN_EnergyB_DJF_AA/RCP45_dST_CAM3Grid_DJF_AA
wAVD_OCN_Feedback_DJF_AA = wAVD_OCN_EnergyB_DJF_AA/wAVD_dST_CAM3Grid_DJF_AA

RCP45_OCN_Feedback_DJF_GA = RCP45_OCN_EnergyB_DJF_GA/RCP45_dST_CAM3Grid_DJF_GA
wAVD_OCN_Feedback_DJF_GA = wAVD_OCN_EnergyB_DJF_GA/wAVD_dST_CAM3Grid_DJF_GA

# %%
#RCP45 Arctic
RCP45_DYNatmos_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Dynamical/RCP45/Seasonal Breakdown/RCP45_DYNatmos_Feedback_DJF_AA.pickle","rb"))
RCP45_RF_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Forcing/RCP45/Seasonal Breakdown/RCP45_RF_Feedback_DJF_AA.pickle","rb"))

CAM3_RCP45_LR_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/RCP45/Seasonal Breakdown/CAM3_RCP45_LR_Feedback_DJF_AA.pickle","rb"))
CAM3_RCP45_WV_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/RCP45/Seasonal Breakdown/CAM3_RCP45_WV_Feedback_DJF_AA.pickle","rb"))
CAM3_RCP45_ALB_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Albedo/RCP45/Seasonal Breakdown/CAM3_RCP45_ALB_Feedback_DJF_AA.pickle","rb"))
CAM3_RCP45_CLD_LW_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_LW_Feedback_DJF_AA.pickle","rb"))
CAM3_RCP45_CLD_SW_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_SW_Feedback_DJF_AA.pickle","rb"))

#RCP45 Global
RCP45_RF_Feedback_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Forcing/RCP45/Seasonal Breakdown/RCP45_RF_Feedback_DJF_GA.pickle","rb"))

CAM3_RCP45_LR_Feedback_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/RCP45/Seasonal Breakdown/CAM3_RCP45_LR_Feedback_DJF_GA.pickle","rb"))
CAM3_RCP45_WV_Feedback_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/RCP45/Seasonal Breakdown/CAM3_RCP45_WV_Feedback_DJF_GA.pickle","rb"))
CAM3_RCP45_ALB_Feedback_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Albedo/RCP45/Seasonal Breakdown/CAM3_RCP45_ALB_Feedback_DJF_GA.pickle","rb"))
CAM3_RCP45_CLD_LW_Feedback_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_LW_Feedback_DJF_GA.pickle","rb"))
CAM3_RCP45_CLD_SW_Feedback_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_SW_Feedback_DJF_GA.pickle","rb"))

#wAVD Arctic
wAVD_DYNatmos_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Dynamical/wAVD/Seasonal Breakdown/wAVD_DYNatmos_Feedback_DJF_AA.pickle","rb"))
wAVD_RF_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Forcing/wAVD/Seasonal Breakdown/wAVD_RF_Feedback_DJF_AA.pickle","rb"))

CAM3_wAVD_LR_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/wAVD/Seasonal Breakdown/CAM3_wAVD_LR_Feedback_DJF_AA.pickle","rb"))
CAM3_wAVD_WV_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/wAVD/Seasonal Breakdown/CAM3_wAVD_WV_Feedback_DJF_AA.pickle","rb"))
CAM3_wAVD_ALB_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Albedo/wAVD/Seasonal Breakdown/CAM3_wAVD_ALB_Feedback_DJF_AA.pickle","rb"))
CAM3_wAVD_CLD_LW_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_LW_Feedback_DJF_AA.pickle","rb"))
CAM3_wAVD_CLD_SW_Feedback_DJF_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_SW_Feedback_DJF_AA.pickle","rb"))

#wAVD Global
wAVD_RF_Feedback_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Forcing/wAVD/Seasonal Breakdown/wAVD_RF_Feedback_DJF_GA.pickle","rb"))

CAM3_wAVD_LR_Feedback_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/wAVD/Seasonal Breakdown/CAM3_wAVD_LR_Feedback_DJF_GA.pickle","rb"))
CAM3_wAVD_WV_Feedback_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/wAVD/Seasonal Breakdown/CAM3_wAVD_WV_Feedback_DJF_GA.pickle","rb"))
CAM3_wAVD_ALB_Feedback_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Albedo/wAVD/Seasonal Breakdown/CAM3_wAVD_ALB_Feedback_DJF_GA.pickle","rb"))
CAM3_wAVD_CLD_LW_Feedback_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_LW_Feedback_DJF_GA.pickle","rb"))
CAM3_wAVD_CLD_SW_Feedback_DJF_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_SW_Feedback_DJF_GA.pickle","rb"))

# %%
StatSig_LR_EnergyB_DJF_AA = stats.mannwhitneyu(\
    CAM3_RCP45_LR_EnergyB_DJF_AA,CAM3_wAVD_LR_EnergyB_DJF_AA,alternative = 'two-sided')
StatSig_ALB_EnergyB_DJF_AA = stats.mannwhitneyu(\
    CAM3_RCP45_ALB_EnergyB_DJF_AA,CAM3_wAVD_ALB_EnergyB_DJF_AA,alternative = 'two-sided')
StatSig_WV_EnergyB_DJF_AA = stats.mannwhitneyu(\
    CAM3_RCP45_WV_EnergyB_DJF_AA,CAM3_wAVD_WV_EnergyB_DJF_AA,alternative = 'two-sided')
StatSig_CLD_LW_EnergyB_DJF_AA = stats.mannwhitneyu(\
    CAM3_RCP45_CLD_LW_EnergyB_DJF_AA,CAM3_wAVD_CLD_LW_EnergyB_DJF_AA,alternative = 'two-sided')
StatSig_CLD_SW_EnergyB_DJF_AA = stats.mannwhitneyu(\
    CAM3_RCP45_CLD_SW_EnergyB_DJF_AA,CAM3_wAVD_CLD_SW_EnergyB_DJF_AA,alternative = 'two-sided')

StatSig_DYNatmos_EnergyB_DJF_AA = stats.mannwhitneyu(\
    wAVD_DYNatmos_EnergyB_DJF_AA,RCP45_DYNatmos_EnergyB_DJF_AA,alternative = 'two-sided')
StatSig_OCN_EnergyB_DJF_AA = stats.mannwhitneyu(\
    wAVD_OCN_EnergyB_DJF_AA,RCP45_OCN_EnergyB_DJF_AA,alternative = 'two-sided')

# %%
StatSig_LR_Feedback_DJF_AA = stats.mannwhitneyu(\
    CAM3_RCP45_LR_Feedback_DJF_AA,CAM3_wAVD_LR_Feedback_DJF_AA,alternative = 'two-sided')
StatSig_ALB_Feedback_DJF_AA = stats.mannwhitneyu(\
    CAM3_RCP45_ALB_Feedback_DJF_AA,CAM3_wAVD_ALB_Feedback_DJF_AA,alternative = 'two-sided')
StatSig_WV_Feedback_DJF_AA = stats.mannwhitneyu(\
    CAM3_RCP45_WV_Feedback_DJF_AA,CAM3_wAVD_WV_Feedback_DJF_AA,alternative = 'two-sided')
StatSig_CLD_LW_Feedback_DJF_AA = stats.mannwhitneyu(\
    CAM3_RCP45_CLD_LW_Feedback_DJF_AA,CAM3_wAVD_CLD_LW_Feedback_DJF_AA,alternative = 'two-sided')
StatSig_CLD_SW_Feedback_DJF_AA = stats.mannwhitneyu(\
    CAM3_RCP45_CLD_SW_Feedback_DJF_AA,CAM3_wAVD_CLD_SW_Feedback_DJF_AA,alternative = 'two-sided')

StatSig_DYNatmos_Feedback_DJF_AA = stats.mannwhitneyu(\
    wAVD_DYNatmos_Feedback_DJF_AA,RCP45_DYNatmos_Feedback_DJF_AA,alternative = 'two-sided')
StatSig_OCN_Feedback_DJF_AA = stats.mannwhitneyu(\
    wAVD_OCN_Feedback_DJF_AA,RCP45_OCN_Feedback_DJF_AA,alternative = 'two-sided')

# %%
print('Arctic Lapse Rate Energy Budget Dec-Feb :',StatSig_LR_EnergyB_DJF_AA)
print('Arctic Albedo Energy Budget Dec-Feb :',StatSig_ALB_EnergyB_DJF_AA)
print('Arctic Water Vapour Energy Budget Dec-Feb :',StatSig_WV_EnergyB_DJF_AA)
print('Arctic Shortwave Cloud Energy Budget Dec-Feb :',StatSig_CLD_SW_EnergyB_DJF_AA)
print('Arctic Longwave Cloud Energy Budget Dec-Feb :',StatSig_CLD_LW_EnergyB_DJF_AA)
print('Arctic PET Energy Budget Dec-Feb :',StatSig_DYNatmos_EnergyB_DJF_AA)
print('Arctic Ocean Heat Storage Energy Budget Dec-Feb :',StatSig_OCN_EnergyB_DJF_AA)
print('\n')
print('Arctic Lapse Rate Feedback Dec-Feb :',StatSig_LR_Feedback_DJF_AA)
print('Arctic Albedo Feedback Dec-Feb :',StatSig_ALB_Feedback_DJF_AA)
print('Arctic Water Vapour Feedback Dec-Feb :',StatSig_WV_Feedback_DJF_AA)
print('Arctic Shortwave Cloud Feedback Dec-Feb :',StatSig_CLD_SW_Feedback_DJF_AA)
print('Arctic Longwave Cloud Feedback Dec-Feb :',StatSig_CLD_LW_Feedback_DJF_AA)
print('Arctic PET Feedback Dec-Feb :',StatSig_DYNatmos_Feedback_DJF_AA)
print('Arctic Ocean Heat Storage Feedback Dec-Feb :',StatSig_OCN_Feedback_DJF_AA)
# Out:
# Arctic Lapse Rate Energy Budget Dec-Feb : MannwhitneyuResult(statistic=0.0, pvalue=0.012185780355344813)
# Arctic Albedo Energy Budget Dec-Feb : MannwhitneyuResult(statistic=18.0, pvalue=0.2962698714842864)
# Arctic Water Vapour Energy Budget Dec-Feb : MannwhitneyuResult(statistic=3.0, pvalue=0.06010280593886631)
# Arctic Shortwave Cloud Energy Budget Dec-Feb : MannwhitneyuResult(statistic=25.0, pvalue=0.012185780355344813)
# Arctic Longwave Cloud Energy Budget Dec-Feb : MannwhitneyuResult(statistic=0.0, pvalue=0.012185780355344813)
# Arctic PET Energy Budget Dec-Feb : MannwhitneyuResult(statistic=3.0, pvalue=0.06010280593886631)
# Arctic Ocean Heat Storage Energy Budget Dec-Feb : MannwhitneyuResult(statistic=3.0, pvalue=0.06010280593886631)
#
#
# Arctic Lapse Rate Feedback Dec-Feb : MannwhitneyuResult(statistic=3.0, pvalue=0.06010280593886631)
# Arctic Albedo Feedback Dec-Feb : MannwhitneyuResult(statistic=25.0, pvalue=0.012185780355344813)
# ...
