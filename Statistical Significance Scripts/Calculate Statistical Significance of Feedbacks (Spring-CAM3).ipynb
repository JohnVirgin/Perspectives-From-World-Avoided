# %%
## Import Packages
import numpy as np
import scipy.stats as stats
import warnings
import pickle
import Area_Avg
from netCDF4 import Dataset
warnings.filterwarnings('ignore')

# %%
#RCP45 Arctic
RCP45_DYNatmos_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Dynamical/RCP45/Seasonal Breakdown/RCP45_DYNatmos_EnergyB_MAM_AA.pickle","rb"))
RCP45_OCN_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Ocean Heat Content/RCP45/Seasonal Breakdown/RCP45_OCN_EnergyB_MAM_AA.pickle","rb"))
RCP45_RF_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Forcing/RCP45/Seasonal Breakdown/RCP45_RF_EnergyB_MAM_AA.pickle","rb"))

CAM3_RCP45_LR_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/RCP45/Seasonal Breakdown/CAM3_RCP45_LR_EnergyB_MAM_AA.pickle","rb"))
CAM3_RCP45_WV_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/RCP45/Seasonal Breakdown/CAM3_RCP45_WV_EnergyB_MAM_AA.pickle","rb"))
CAM3_RCP45_ALB_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Albedo/RCP45/Seasonal Breakdown/CAM3_RCP45_ALB_EnergyB_MAM_AA.pickle","rb"))
CAM3_RCP45_CLD_LW_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_LW_EnergyB_MAM_AA.pickle","rb"))
CAM3_RCP45_CLD_SW_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_SW_EnergyB_MAM_AA.pickle","rb"))

#RCP45 Global
RCP45_OCN_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Ocean Heat Content/RCP45/Seasonal Breakdown/RCP45_OCN_EnergyB_MAM_GA.pickle","rb"))
RCP45_RF_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Forcing/RCP45/Seasonal Breakdown/RCP45_RF_EnergyB_MAM_GA.pickle","rb"))

CAM3_RCP45_LR_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/RCP45/Seasonal Breakdown/CAM3_RCP45_LR_EnergyB_MAM_GA.pickle","rb"))
CAM3_RCP45_WV_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/RCP45/Seasonal Breakdown/CAM3_RCP45_WV_EnergyB_MAM_GA.pickle","rb"))
CAM3_RCP45_ALB_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Albedo/RCP45/Seasonal Breakdown/CAM3_RCP45_ALB_EnergyB_MAM_GA.pickle","rb"))
CAM3_RCP45_CLD_LW_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_LW_EnergyB_MAM_GA.pickle","rb"))
CAM3_RCP45_CLD_SW_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_SW_EnergyB_MAM_GA.pickle","rb"))

#wAVD Arctic
wAVD_DYNatmos_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Dynamical/wAVD/Seasonal Breakdown/wAVD_DYNatmos_EnergyB_MAM_AA.pickle","rb"))
wAVD_OCN_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Ocean Heat Content/wAVD/Seasonal Breakdown/wAVD_OCN_EnergyB_MAM_AA.pickle","rb"))
wAVD_RF_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Forcing/wAVD/Seasonal Breakdown/wAVD_RF_EnergyB_MAM_AA.pickle","rb"))

CAM3_wAVD_LR_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/wAVD/Seasonal Breakdown/CAM3_wAVD_LR_EnergyB_MAM_AA.pickle","rb"))
CAM3_wAVD_WV_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/wAVD/Seasonal Breakdown/CAM3_wAVD_WV_EnergyB_MAM_AA.pickle","rb"))
CAM3_wAVD_ALB_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Albedo/wAVD/Seasonal Breakdown/CAM3_wAVD_ALB_EnergyB_MAM_AA.pickle","rb"))
CAM3_wAVD_CLD_LW_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_LW_EnergyB_MAM_AA.pickle","rb"))
CAM3_wAVD_CLD_SW_EnergyB_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_SW_EnergyB_MAM_AA.pickle","rb"))

#wAVD Global
wAVD_OCN_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Ocean Heat Content/wAVD/Seasonal Breakdown/wAVD_OCN_EnergyB_MAM_GA.pickle","rb"))
wAVD_RF_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Forcing/wAVD/Seasonal Breakdown/wAVD_RF_EnergyB_MAM_GA.pickle","rb"))

CAM3_wAVD_LR_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/wAVD/Seasonal Breakdown/CAM3_wAVD_LR_EnergyB_MAM_GA.pickle","rb"))
CAM3_wAVD_WV_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/wAVD/Seasonal Breakdown/CAM3_wAVD_WV_EnergyB_MAM_GA.pickle","rb"))
CAM3_wAVD_ALB_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Albedo/wAVD/Seasonal Breakdown/CAM3_wAVD_ALB_EnergyB_MAM_GA.pickle","rb"))
CAM3_wAVD_CLD_LW_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_LW_EnergyB_MAM_GA.pickle","rb"))
CAM3_wAVD_CLD_SW_EnergyB_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_SW_EnergyB_MAM_GA.pickle","rb"))

# %%
#CAM3 Horizontal resolution grid
LLL3 = Dataset('Kernels/Interpolated/CAM3_Kernels.nc')
CAM3_Lat = np.squeeze(LLL3.variables['lat'])
CAM3_Lon = np.squeeze(LLL3.variables['lon'])

#Lists for iterating
Months = np.arange(0,12)
FP_Ensemble_Members = np.arange(0,5)

RCP45_dST_CAM3Grid = np.swapaxes(pickle.load(open(\
   "Future Projection CC Responses/RCP45_dST_CAM3Grid.pickle","rb"),encoding='latin1'),2,3)

wAVD_dST_CAM3Grid = np.swapaxes(pickle.load(open(\
   "Future Projection CC Responses/wAVD_dST_CAM3Grid.pickle","rb"),encoding='latin1'),2,3)

RCP45_dST_CAM3Grid_AA = np.zeros([5,12])
RCP45_dST_CAM3Grid_GA = np.zeros([5,12])

wAVD_dST_CAM3Grid_AA = np.zeros([5,12])
wAVD_dST_CAM3Grid_GA = np.zeros([5,12])

for i in range(FP_Ensemble_Members.size):
    RCP45_dST_CAM3Grid_AA[i,:] = Area_Avg.LatLonavg_Time(\
    RCP45_dST_CAM3Grid[i,:,54:,:],CAM3_Lat[54:],CAM3_Lon)
    
    RCP45_dST_CAM3Grid_GA[i,:] = Area_Avg.LatLonavg_Time(\
    RCP45_dST_CAM3Grid[i,:,:,:],CAM3_Lat,CAM3_Lon)
    
    wAVD_dST_CAM3Grid_AA[i,:] = Area_Avg.LatLonavg_Time(\
    wAVD_dST_CAM3Grid[i,:,54:,:],CAM3_Lat[54:],CAM3_Lon)
    
    wAVD_dST_CAM3Grid_GA[i,:] = Area_Avg.LatLonavg_Time(\
    wAVD_dST_CAM3Grid[i,:,:,:],CAM3_Lat,CAM3_Lon)
    
RCP45_dST_CAM3Grid_MAM_AA = np.mean(RCP45_dST_CAM3Grid_AA[:,2:5],axis=1)
RCP45_dST_CAM3Grid_MAM_GA = np.mean(RCP45_dST_CAM3Grid_GA[:,2:5],axis=1)

wAVD_dST_CAM3Grid_MAM_AA = np.mean(wAVD_dST_CAM3Grid_AA[:,2:5],axis=1)
wAVD_dST_CAM3Grid_MAM_GA = np.mean(wAVD_dST_CAM3Grid_GA[:,2:5],axis=1)

RCP45_OCN_Feedback_MAM_AA = RCP45_OCN_EnergyB_MAM_AA/RCP45_dST_CAM3Grid_MAM_AA
wAVD_OCN_Feedback_MAM_AA = wAVD_OCN_EnergyB_MAM_AA/wAVD_dST_CAM3Grid_MAM_AA

RCP45_OCN_Feedback_MAM_GA = RCP45_OCN_EnergyB_MAM_GA/RCP45_dST_CAM3Grid_MAM_GA
wAVD_OCN_Feedback_MAM_GA = wAVD_OCN_EnergyB_MAM_GA/wAVD_dST_CAM3Grid_MAM_GA

# %%
#RCP45 Arctic
RCP45_DYNatmos_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Dynamical/RCP45/Seasonal Breakdown/RCP45_DYNatmos_Feedback_MAM_AA.pickle","rb"))
RCP45_RF_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Forcing/RCP45/Seasonal Breakdown/RCP45_RF_Feedback_MAM_AA.pickle","rb"))

CAM3_RCP45_LR_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/RCP45/Seasonal Breakdown/CAM3_RCP45_LR_Feedback_MAM_AA.pickle","rb"))
CAM3_RCP45_WV_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/RCP45/Seasonal Breakdown/CAM3_RCP45_WV_Feedback_MAM_AA.pickle","rb"))
CAM3_RCP45_ALB_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Albedo/RCP45/Seasonal Breakdown/CAM3_RCP45_ALB_Feedback_MAM_AA.pickle","rb"))
CAM3_RCP45_CLD_LW_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_LW_Feedback_MAM_AA.pickle","rb"))
CAM3_RCP45_CLD_SW_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_SW_Feedback_MAM_AA.pickle","rb"))

#RCP45 Global
RCP45_RF_Feedback_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Forcing/RCP45/Seasonal Breakdown/RCP45_RF_Feedback_MAM_GA.pickle","rb"))

CAM3_RCP45_LR_Feedback_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/RCP45/Seasonal Breakdown/CAM3_RCP45_LR_Feedback_MAM_GA.pickle","rb"))
CAM3_RCP45_WV_Feedback_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/RCP45/Seasonal Breakdown/CAM3_RCP45_WV_Feedback_MAM_GA.pickle","rb"))
CAM3_RCP45_ALB_Feedback_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Albedo/RCP45/Seasonal Breakdown/CAM3_RCP45_ALB_Feedback_MAM_GA.pickle","rb"))
CAM3_RCP45_CLD_LW_Feedback_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_LW_Feedback_MAM_GA.pickle","rb"))
CAM3_RCP45_CLD_SW_Feedback_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/RCP45/Seasonal Breakdown/CAM3_RCP45_CLD_SW_Feedback_MAM_GA.pickle","rb"))

#wAVD Arctic
wAVD_DYNatmos_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Dynamical/wAVD/Seasonal Breakdown/wAVD_DYNatmos_Feedback_MAM_AA.pickle","rb"))
wAVD_RF_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Forcing/wAVD/Seasonal Breakdown/wAVD_RF_Feedback_MAM_AA.pickle","rb"))

CAM3_wAVD_LR_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/wAVD/Seasonal Breakdown/CAM3_wAVD_LR_Feedback_MAM_AA.pickle","rb"))
CAM3_wAVD_WV_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/wAVD/Seasonal Breakdown/CAM3_wAVD_WV_Feedback_MAM_AA.pickle","rb"))
CAM3_wAVD_ALB_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Albedo/wAVD/Seasonal Breakdown/CAM3_wAVD_ALB_Feedback_MAM_AA.pickle","rb"))
CAM3_wAVD_CLD_LW_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_LW_Feedback_MAM_AA.pickle","rb"))
CAM3_wAVD_CLD_SW_Feedback_MAM_AA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_SW_Feedback_MAM_AA.pickle","rb"))

#wAVD Global
wAVD_RF_Feedback_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Forcing/wAVD/Seasonal Breakdown/wAVD_RF_Feedback_MAM_GA.pickle","rb"))

CAM3_wAVD_LR_Feedback_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Lapse Rate/wAVD/Seasonal Breakdown/CAM3_wAVD_LR_Feedback_MAM_GA.pickle","rb"))
CAM3_wAVD_WV_Feedback_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Water Vapour/wAVD/Seasonal Breakdown/CAM3_wAVD_WV_Feedback_MAM_GA.pickle","rb"))
CAM3_wAVD_ALB_Feedback_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Albedo/wAVD/Seasonal Breakdown/CAM3_wAVD_ALB_Feedback_MAM_GA.pickle","rb"))
CAM3_wAVD_CLD_LW_Feedback_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_LW_Feedback_MAM_GA.pickle","rb"))
CAM3_wAVD_CLD_SW_Feedback_MAM_GA = pickle.load(open(\
"ENERGY BUDGET/Cloud/wAVD/Seasonal Breakdown/CAM3_wAVD_CLD_SW_Feedback_MAM_GA.pickle","rb"))

# %%
StatSig_LR_EnergyB_MAM_AA = stats.mannwhitneyu(\
    CAM3_RCP45_LR_EnergyB_MAM_AA,CAM3_wAVD_LR_EnergyB_MAM_AA,alternative = 'two-sided')
StatSig_ALB_EnergyB_MAM_AA = stats.mannwhitneyu(\
    CAM3_RCP45_ALB_EnergyB_MAM_AA,CAM3_wAVD_ALB_EnergyB_MAM_AA,alternative = 'two-sided')
StatSig_WV_EnergyB_MAM_AA = stats.mannwhitneyu(\
    CAM3_RCP45_WV_EnergyB_MAM_AA,CAM3_wAVD_WV_EnergyB_MAM_AA,alternative = 'two-sided')
StatSig_CLD_LW_EnergyB_MAM_AA = stats.mannwhitneyu(\
    CAM3_RCP45_CLD_LW_EnergyB_MAM_AA,CAM3_wAVD_CLD_LW_EnergyB_MAM_AA,alternative = 'two-sided')

StatSig_CLD_SW_EnergyB_MAM_AA = stats.mannwhitneyu(\
    CAM3_wAVD_CLD_SW_EnergyB_MAM_AA,CAM3_RCP45_CLD_SW_EnergyB_MAM_AA,alternative = 'two-sided')

StatSig_DYNatmos_EnergyB_MAM_AA = stats.mannwhitneyu(\
    RCP45_DYNatmos_EnergyB_MAM_AA,wAVD_DYNatmos_EnergyB_MAM_AA,alternative = 'two-sided')
StatSig_OCN_EnergyB_MAM_AA = stats.mannwhitneyu(\
    RCP45_OCN_EnergyB_MAM_AA,wAVD_OCN_EnergyB_MAM_AA,alternative = 'two-sided')

# %%
StatSig_LR_Feedback_MAM_AA = stats.mannwhitneyu(\
    CAM3_RCP45_LR_Feedback_MAM_AA,CAM3_wAVD_LR_Feedback_MAM_AA,alternative = 'two-sided')

StatSig_ALB_Feedback_MAM_AA = stats.mannwhitneyu(\
    CAM3_wAVD_ALB_Feedback_MAM_AA,CAM3_RCP45_ALB_Feedback_MAM_AA,alternative = 'two-sided')

StatSig_WV_Feedback_MAM_AA = stats.mannwhitneyu(\
    CAM3_RCP45_WV_Feedback_MAM_AA,CAM3_wAVD_WV_Feedback_MAM_AA,alternative = 'two-sided')
StatSig_CLD_LW_Feedback_MAM_AA = stats.mannwhitneyu(\
    CAM3_RCP45_CLD_LW_Feedback_MAM_AA,CAM3_wAVD_CLD_LW_Feedback_MAM_AA,alternative = 'two-sided')

StatSig_CLD_SW_Feedback_MAM_AA = stats.mannwhitneyu(\
    CAM3_wAVD_CLD_SW_Feedback_MAM_AA,CAM3_RCP45_CLD_SW_Feedback_MAM_AA,alternative = 'two-sided')

StatSig_DYNatmos_Feedback_MAM_AA = stats.mannwhitneyu(\
    RCP45_DYNatmos_Feedback_MAM_AA,wAVD_DYNatmos_Feedback_MAM_AA,alternative = 'two-sided')
StatSig_OCN_Feedback_MAM_AA = stats.mannwhitneyu(\
    RCP45_OCN_Feedback_MAM_AA,wAVD_OCN_Feedback_MAM_AA,alternative = 'two-sided')

# %%
print('Arctic Lapse Rate Energy Budget March-May :',StatSig_LR_EnergyB_MAM_AA)
print('Arctic Albedo Energy Budget March-May :',StatSig_ALB_EnergyB_MAM_AA)
print('Arctic Water Vapour Energy Budget March-May :',StatSig_WV_EnergyB_MAM_AA)
print('Arctic Shortwave Cloud Energy Budget March-May :',StatSig_CLD_SW_EnergyB_MAM_AA)
print('Arctic Longwave Cloud Energy Budget March-May :',StatSig_CLD_LW_EnergyB_MAM_AA)
print('Arctic PET Energy Budget March-May :',StatSig_DYNatmos_EnergyB_MAM_AA)
print('Arctic Ocean Heat Storage Energy Budget March-May :',StatSig_OCN_EnergyB_MAM_AA)
print('\n')
print('Arctic Lapse Rate Feedback March-May :',StatSig_LR_Feedback_MAM_AA)
print('Arctic Albedo Feedback March-May :',StatSig_ALB_Feedback_MAM_AA)
print('Arctic Water Vapour Feedback March-May :',StatSig_WV_Feedback_MAM_AA)
print('Arctic Shortwave Cloud Feedback March-May :',StatSig_CLD_SW_Feedback_MAM_AA)
print('Arctic Longwave Cloud Feedback March-May :',StatSig_CLD_LW_Feedback_MAM_AA)
print('Arctic PET Feedback March-May :',StatSig_DYNatmos_Feedback_MAM_AA)
print('Arctic Ocean Heat Storage Feedback March-May :',StatSig_OCN_Feedback_MAM_AA)
# Out:
# Arctic Lapse Rate Energy Budget March-May : MannwhitneyuResult(statistic=3.0, pvalue=0.06010280593886631)
# Arctic Albedo Energy Budget March-May : MannwhitneyuResult(statistic=7.0, pvalue=0.2962698714842864)
# Arctic Water Vapour Energy Budget March-May : MannwhitneyuResult(statistic=0.0, pvalue=0.012185780355344813)
# Arctic Shortwave Cloud Energy Budget March-May : MannwhitneyuResult(statistic=0.0, pvalue=0.012185780355344813)
# Arctic Longwave Cloud Energy Budget March-May : MannwhitneyuResult(statistic=0.0, pvalue=0.012185780355344813)
# Arctic PET Energy Budget March-May : MannwhitneyuResult(statistic=0.0, pvalue=0.012185780355344813)
# Arctic Ocean Heat Storage Energy Budget March-May : MannwhitneyuResult(statistic=1.0, pvalue=0.02157174794772092)
#
#
# Arctic Lapse Rate Feedback March-May : MannwhitneyuResult(statistic=12.0, pvalue=1.0)
# Arctic Albedo Feedback March-May : MannwhitneyuResult(statistic=0.0, pvalue=0.012185780355344813)
# ...
